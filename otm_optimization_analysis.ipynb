# %%
import numpy as np
import timeit
import pandas as pd

# %% [markdown]
# ## Definições
# <hr/>

# %%
def f(x):
    x = np.array(x)
    x1 = x[0][0]
    x2 =x[1][0]
    return 3**(1/(x1+x2))+x1**2+x2**2

# %%
def Gradiente(x):
    x = np.array(x)
    x1 = x[0][0]
    x2 =x[1][0]
    return np.array([[2*x1-(np.log(3)*np.exp(np.log(3)/(x1+x2)))/(x1+x2)**2],
            [2*x2-(np.log(3)*np.exp(np.log(3)/(x1+x2)))/(x1+x2)**2]])

# %%
def Heissiana(x):
    x = np.array(x)
    x1 = x[0][0]
    x2 =x[1][0]
    return np.array([[2 - (np.log(3)*(-np.log(3)*np.exp(np.log(3)/(x1+x2))-2*np.exp(np.log(3)/(x1+x2))))/(x1+x2)**4, -np.log(3)*(-np.log(3)*np.exp(np.log(3)/(x1+x2))-2*np.exp(np.log(3)/(x1+x2)))/(x1+x2)**4],

            [-np.log(3)*(-np.log(3)*np.exp(np.log(3)/(x1+x2))-2*np.exp(np.log(3)/(x1+x2)))/(x1+x2)**4 ,2 - (np.log(3)*(-np.log(3)*np.exp(np.log(3)/(x1+x2))-2*np.exp(np.log(3)/(x1+x2))*(x1+x2)))/(x1+x2)**4]])

# %%
def definida_positiva_2x2(matrix):    
    if matrix[0][0] > 0 and np.linalg.det(matrix)>0:
        return True
    else: 
        return False

# %%
def is_invertible(a):
    return a.shape[0] == a.shape[1] and np.linalg.matrix_rank(a) == a.shape[0]

# %%
def test_combinations(search, method, maxiter, tol):
    result = {
        "start": [],
        "gamma": [],
        "eta": [],
        "Armijo Iterations": [],
        "Method Iterations": [],
        "Optical Point Found": [],
        "Optical Value Found": [],
        "Time": []
    }
    for point in search['start']:
        for gamma in search['gamma']:
            for eta in search['eta']:
                start = timeit.default_timer()
                met =  method(point, tol, maxiter, gamma, eta)
                stop = timeit.default_timer()
                result["start"].append(point)
                result["gamma"].append(gamma)
                result["eta"].append(eta)
                result["Armijo Iterations"].append(met[2])
                result["Method Iterations"].append(met[1])
                result["Optical Point Found"].append(met[0])
                result["Optical Value Found"].append(f(met[0]))
                result["Time"].append(stop - start)

    return result

# %%
search = {
    "start": [
        [[0.5], [0.5]], 
        [[-1], [-1]], 
        [[-6000], [-5000]],
        [[6000],[5000]],
        [[5], [-0.5]],
        [[-5], [0.5]] 
    ],
    "gamma": [
        0.8,
        0.65,
        0.5
    ],
    "eta": [
        0.25,
        0.1
    ],
}

# %% [markdown]
# # Estudo da Função
# <hr/>

# %% [markdown]
# ## Primeira foto da função
#
# ![Geogebra function](images/function.png)
#
#
#
# Apenas pela observação direta da função podemos visualizar criada pelo geogebra:
# 1. Há uma uma descontinuidade na função na reta (x = -y);
# 2. Há um mínimo local no primeiro quadrante (x > 0 e y > 0);
# 3. No domínio observado, a função é convexa.

# %% [markdown]
# ## Decontinuidade
#
# Devido a razão $\frac{1}{x_1 + x_2}$ presente no exponente do 3, temos que:
#
# $$
# \lim_{x_1 \to -x_2} f(x_1, x_2) = \infty \text{  e  } \lim_{x_2 \to -x_1} f(x_1, x_2) = \infty
# $$
# Consequentemente,
# $$
# \lim_{(x_1, x_2) \to (0, 0)} f(x_1, x_2) = \infty
# $$
# Isso significa que a função não está definida no ponto (0, 0) e, portanto, ele não pode ser o mínimo global da função como aparenta na imagem.\\

# %% [markdown]
# ## Pontos estacionários
#
# Para calcular os pontos estácionários da função, vamos igualar seu gradiante a zero
#
# $$
# \nabla f(x_1, x_2) = \begin{bmatrix}
#         2x - \frac{(\ln{3}e^{\frac{\ln{3}}{x + y}})}{(x + y)^2}\\
#         2y - \frac{(\ln{3}e^{\frac{\ln{3}}{x + y}})}{(x + y)^2}
# \end{bmatrix} = 0
# $$
#
# Assim, obtemos um sistema de equações que pode ser resolvido subtraindo a primeira equação da segunda:
#
# $$
#         2x - 2y =  0\\
#         x = y
# $$
#
# Isso indica que os pontos estacionários estão no domnínio estabelecido pela reta x = y. <br>
# Vamos calcular e visualizar o que acontece quando o hiperplano formado pela reta intercepta a função.
#
# $$
#         g(x) = f(x, x) = 3^{\frac{1}{2x}} + 2x^2
# $$
#
#
# Intersseção em 3D            |  Intersseção em 2D (curva formada no eixo z e no eixo x)
# :-------------------------:|:-------------------------:
# ![](images/hiperplano.png)  |  ![](images/intersse.png)
#
#
#
# Conseguimos observar o <strong>mínimo local</strong> mencionado anteriormente e aproximação feita pelo Geogebra do seu valor, mas gostaríamos de calcular esse valor numericamente. <br>Como não foi possível terminar a resolução do sistema de equações acima com os métodos tradicionais, optamos por usar uma <strong>aproximação de Taylor de terceira ordem </strong> para aproximar a função $3^{\frac{1}{2x}}$ na forma de um polinômio.

# %% [markdown]
#  - Série de Taylor desenvoldida:
# $$
#         3^{\frac{1}{2x}} \approx \sum_{n = -3}^0 \frac{x^n (\frac{2}{\ln{3}})^n}{(-n!)} = 1\:+\:\frac{0.5493061443340549}{x}\:+\:\frac{0.15086862010157276}{x^2}+\frac{0.02762435333633141}{x^3}
# $$
# <p align="center">
#   <img src="images/taylo.png" />
# </p>

# %%
def CoeffTaylor(n):
    return (2/np.log(3))**n/(np.math.factorial(-n))
CoeffTaylor(0), CoeffTaylor(-1), CoeffTaylor(-2), CoeffTaylor(-3)
# Out:
# (1.0, 0.5493061443340549, 0.15086862010157276, 0.02762435333633141)

# %% [markdown]
# Dessa forma, foi possível encontrar um valor aproximadO para o ponto crítico da função algebricamente:
#
# $$
#
#         g'(x) = 4x-\frac{0.5493}{x^2}-\frac{0.30172}{x^3}-\frac{0.08286}{x^4}\\
#          4x-\frac{0.5493}{x^2}-\frac{0.30172}{x^3}-\frac{0.08286}{x^4} = 0\\
#         \therefore x = 0.66714
# $$
# O ponto estacionário encontrado foi ~(0.66714, 0.66714) com f(x, y) = 16832, que é muito parecido com o ponto aproximado pelo software ~(0.67633,0.67633) com f(x, y) = 3.16767

# %% [markdown]
# ## Convexidade
#
# Para analisar a convexidade vamos avaliar a Hessiana da função:
#
# Seja w = $\frac{\ln{(3)} (\ln{(3)} e^{\frac{\ln{3}}{x+y}} + 2 (x + y) e^{\frac{\ln{3}}{x+y}})}{(x+y)^4}$, a Hessiana pode ser escrita da seguinte forma:
#
#
# $$
# H = \begin{bmatrix}
# 2+w & w \\
# w & 2+w
# \end{bmatrix}
# $$
# Sabemos que para um matriz ser definida positiva, a sua determinante e a determinante de suas submatrices precisa ser maior que zero:
#
#
# $$
#     det([2+w]) = 2 + w > 0 \\
#     det(H) = (2+w)^2 - w^2 > 0
# $$
#
# Se x > 0 e y > 0, w é sempre postivo o que torna as duas desigualdades acima verdadeiras. Então, a matriz é definida positiva nesse domínio e portanto convexa. Isso já indica que nosso ponto estacionário é um ponto de mínimo, vamos conferir:

# %%
def definida_positiva_2x2(matrix):    
    if matrix[0][0] > 0 and np.linalg.det(matrix)>0:
        return True
    else: 
        return False
    
heissiana_ponto_critico = Heissiana([[0.66714],[0.66714]])
definida_positiva_2x2(heissiana_ponto_critico)
# Out:
# True

# %% [markdown]
# Provamos, então, que o ponto crítico encontrado nesta análise é um ponto de <strong>mínimo</strong>. <br>
# É fácil perceber que ele é <strong>local</strong>, pois existem valores em que a função é menor.

# %%
f([[-1], [-1]])
# Out:
# 2.5773502691896257

# %% [markdown]
# ## Apenas mínimo local
#
# A função analisada é um caso exepcional em que há um mínimo local, mas não há um mínimo global. <br>
#
# Pela definição: c é um mínimo global da função f(x), se f(c)≥f(x) para todo x no domínio de f.<br>
# Como o ponto (0, 0) não está definido e ao domínio da função é $\mathcal{R^2}$, sempre podemos encontrar um ponto c cada vez mais próximo de zero que torna a função cada vez menor, o que foge da definição.

# %% [markdown]
# # Estudo dos Pontos
# <hr/>

# %% [markdown]
# <p align="center">
#   <img src="images/Pontos.Jpeg" />
# </p>
#
# - Dividimos nossa função em duas partes:
#     1) Contém o ponto descontínuo (0,0).
#     2) Contém o mínimo local.

# %% [markdown]
# - Separamos 6 pontos tendo como base na parte da função e quadrante do domínio.
#     - O ponto (-1,-1) (ponto A da imagem) que está próximo ao ponto não definido de f(x). Esperamos que este ponto  convirja para um ponto próximo de (0,0), até chegar na tolerância devido a sua proximidade a descontinuidade.
#     - P ponto (0.5,0.5) (Ponto B da imagem), ponto próximo ao mímimo local de f(x). Esperamos que este ponto convirja para o mínimo local.
#     - Os pontos (-6000,-5000) e (6000,5000) que são suficientemente grandes para vermos o funcionamento dos métodos com números grandes e a convergencia do método. O fato desses valores serem grandes pode fazer com que o deslocamento seja grande mesmo com um passo pequeno e queríamos estudar esse comportamento.
#     - O ponto (5, -0.5), pertencente a segunda parte (ponto C), e (-5, 0.5), pertencente a primeira parte (ponto D), são pontos ligeiramente distantes do ponto de descontinuidade e do ponto mínimo de f(x) respectivamente. Esperamos que cada ponto tenha convergencia a pontos de suas respectivas partes dependendo do tamanho do passo. Isso porque é necessário um passo suficientemente grande para o ponto D fugir da descontinuidade e convergir para o mínimo logal e, por outro lado, passos grandes podem fazer com que C caia na descontinuidade e não convirja.

# %% [markdown]
# # Implementação dos métodos
# <hr>

# %% [markdown]
# ### Busca de Armijo

# %%
def Armijo(x,gama,d,n):
    t = 1
    k = 0
    d = np.array(d)
    x = np.array(x)
    while f(x + t*d) > f(x) + n*t*(np.transpose(Gradiente(x))@d):
        t=gama*t
        k = k+1
    return [t,k]

# %% [markdown]
# ### Método do Gradiente

# %%
def met_gradiente(x,tol,maxiter,gama,n, debug=False):
    x = np.array(x)
    m = 0
    k = 0
    while np.linalg.norm(Gradiente(x)) > tol and m < maxiter:
        d = - Gradiente(x)
        ar = Armijo(x,gama,d,n)
        k = k + ar[1]
        t = ar[0]
        x = x + t*d
        m = m + 1
    return [x,m,k]

# %%
tol = 0.0001
maxiter = 1000
result = test_combinations(search, met_gradiente, maxiter, tol)       
grad_res = pd.DataFrame.from_records(result)    
grad_res[grad_res["eta"] == 0.25]
# Out:
# C:\Users\mwuillau\AppData\Local\Temp\ipykernel_2572\3196596769.py:5: RuntimeWarning: overflow encountered in double_scalars
#   return 3**(1/(x1+x2))+x1**2+x2**2
# C:\Users\mwuillau\AppData\Local\Temp\ipykernel_2572\3196596769.py:5: RuntimeWarning: divide by zero encountered in double_scalars
#   return 3**(1/(x1+x2))+x1**2+x2**2
#     Armijo Iterations  Method Iterations  \
# 0                  73                  9
# 2                  30                  7
# 4                  13                  4
# 6                  26                  6
# 8                  13                  6
# 10                 22                 11
# 12                127                 23
# 14                 20                 13
# 16                 48                 24
# 18                 34                 12
# 20                 21                 13
# 22                 43                 20
# 24                 33                  8
# 26                 18                  8
# 28                 17                  7
# 30                123                 19
# 32                 64                 19
# 34                 35                 17
#
#                                   Optical Point Found  Optical Value Found  \
# 0        [[0.6763370143192518], [0.6763370143192518]]         3.167673e+00
# 2        [[0.6763255367588685], [0.6763255367588685]]         3.167673e+00
# 4        [[0.6763349644096142], [0.6763349644096142]]         3.167673e+00
# 6   [[-8.873752021730419e-06], [-8.873752021730419...         1.574869e-10
# 8   [[-1.1955435295191822e-05], [-1.19554352951918...         2.858649e-10
# 10  [[-1.8035048834030365e-05], [-1.80350488340303...         6.505260e-10
# 12        [[0.6763537339011317], [0.676328007051467]]         3.167673e+00
# 14  [[-3.621000219235728e-05], [-1.185998004600115...         1.451823e-09
# 16  [[-3.534388699473392e-05], [2.4260757780656653...         1.837775e-09
# 18  [[-4.091205876717821e-05], [-1.484462071771027...         1.894159e-09
# 20  [[-2.9544023456023636e-05], [-1.69631786804064...         1.160599e-09
# 22       [[0.6763301101610175], [0.6763301101610175]]         3.167673e+00
# 24  [[-2.7947188071567687e-05], [2.083066036756106...         1.214962e-09
# 26  [[-2.5409496783885865e-05], [1.737443573237245...         9.475135e-10
# 28       [[0.6763341471747903], [0.6763341471747903]]         3.167673e+00
# 30       [[0.6763075645566453], [0.6763419604293337]]         3.167673e+00
# 32       [[0.6763206087755638], [0.6763528526664212]]         3.167673e+00
# 34  [[-3.8396370076204405e-05], [2.454613480660809...         2.076794e-09
#
#         Time   eta  gamma               start
# 0   0.003673  0.25   0.80      [[0.5], [0.5]]
# 2   0.001174  0.25   0.65      [[0.5], [0.5]]
# 4   0.000591  0.25   0.50      [[0.5], [0.5]]
# 6   0.001411  0.25   0.80        [[-1], [-1]]
# 8   0.000850  0.25   0.65        [[-1], [-1]]
# 10  0.001830  0.25   0.50        [[-1], [-1]]
# 12  0.010243  0.25   0.80  [[-6000], [-5000]]
# 14  0.003386  0.25   0.65  [[-6000], [-5000]]
# 16  0.004341  0.25   0.50  [[-6000], [-5000]]
# 18  0.002526  0.25   0.80    [[6000], [5000]]
# 20  0.002334  0.25   0.65    [[6000], [5000]]
# 22  0.002452  0.25   0.50    [[6000], [5000]]
# 24  0.002909  0.25   0.80       [[5], [-0.5]]
# 26  0.000965  0.25   0.65       [[5], [-0.5]]
# 28  0.001181  0.25   0.50       [[5], [-0.5]]
# 30  0.004931  0.25   0.80       [[-5], [0.5]]
# 32  0.003363  0.25   0.65       [[-5], [0.5]]
# 34  0.002346  0.25   0.50       [[-5], [0.5]]

# %% [markdown]
# #### Conclusões
# 1. O ponto (0.5, 0.5) é próximo do mínimo local e por consequência converge para o mínimo local
# 2. O ponto (-1, -1) é próximo de (0, 0) e por consequência converge para valores próximos de (0, 0)
# 3. O ponto (5, -0.5), que pertencem a segunda parte da função, para passos grandes pula e converge pra próximo de (0, 0) e para passos pequenos converge para o mínimo local
# 4. O ponto (-5, 0.5), que pertencem a primeira parte da função, para passos grandes pula e converge para o mínimo local e para passos pequenos converge para próximo de (0, 0)

# %% [markdown]
# ### Método de Newton

# %%
def met_newton(x,tol,maxiter,gama,n, debug=False):
    x = np.array(x)
    m = 0
    k = 0
    df = 1
    inv = 1
    while np.linalg.norm(Gradiente(x)) > tol and m < maxiter:
        d = - (np.linalg.inv(Heissiana(x)))@Gradiente(x)
        ar = Armijo(x,gama,d,n)
        k = k + ar[1]
        t = ar[0]
        x = x + t*d
        m = m + 1
        k = k+1
        if debug:
            df *= definida_positiva_2x2(Heissiana(x))
            inv *=  is_invertible(Heissiana(x))
            print("\nIteração: " , m)
            print(20*"-")
            print("Ponto:\n" ,x)
            print("Hessiana:\n", Heissiana(x))
            print("Definida Positiva:\n", definida_positiva_2x2(Heissiana(x)))
            print("Singular:\n", not is_invertible(Heissiana(x)))
    if debug:
        return [x,m,k, df, inv] 
    else: 
        return [x,m,k]

# %%
tol = 0.0001
maxiter = 1000
result = test_combinations(search, met_newton, maxiter, tol)       
newton_res = pd.DataFrame.from_records(result)   
newton_res[newton_res["eta"] == 0.25]
# Out:
# C:\Users\mwuillau\AppData\Local\Temp\ipykernel_2572\3196596769.py:5: RuntimeWarning: divide by zero encountered in double_scalars
#   return 3**(1/(x1+x2))+x1**2+x2**2
# C:\Users\mwuillau\AppData\Local\Temp\ipykernel_2572\3196596769.py:5: RuntimeWarning: overflow encountered in double_scalars
#   return 3**(1/(x1+x2))+x1**2+x2**2
#     Armijo Iterations  Method Iterations  \
# 0                   6                  6
# 2                   6                  6
# 4                   6                  6
# 6              154962               1000
# 8               90775               1000
# 10                 26                 14
# 12             162137               1000
# 14              90108               1000
# 16                 29                 16
# 18                 18                 12
# 20                 22                 13
# 22                 31                 18
# 24                  8                  7
# 26                  8                  7
# 28                  9                  7
# 30             151547               1000
# 32              79763               1000
# 34                 14                  8
#
#                                   Optical Point Found  Optical Value Found  \
# 0        [[0.6763327501437573], [0.6763281514789622]]         3.167673e+00
# 2        [[0.6763327501437573], [0.6763281514789622]]         3.167673e+00
# 4        [[0.6763327501437573], [0.6763281514789622]]         3.167673e+00
# 6    [[-0.06787345025363754], [-0.14197059824577488]]         3.008728e-02
# 8      [[-0.3797911180521609], [-0.2960744738152126]]         4.287167e-01
# 10  [[-2.5530470568192873e-05], [-2.45032780931528...         1.252216e-09
# 12      [[-0.3594177907609244], [-0.309642320351908]]         4.186475e-01
# 14     [[-0.4237923470116344], [0.26260390832536934]]         2.496572e-01
# 16  [[-1.5747819714917455e-14], [-8.68402572073989...         3.234061e-28
# 18       [[0.6763342609151929], [0.6763225743104986]]         3.167673e+00
# 20       [[0.6763510245154214], [0.6763128681700242]]         3.167673e+00
# 22        [[0.6763498513266573], [0.676320347996509]]         3.167673e+00
# 24       [[0.6763321171469624], [0.6763281020734625]]         3.167673e+00
# 26       [[0.6763357429995785], [0.6763208859147798]]         3.167673e+00
# 28       [[0.6763572602045668], [0.6763023663431386]]         3.167673e+00
# 30     [[-0.5134942904806219], [0.10560571588280158]]         3.424786e-01
# 32    [[-0.07607219974621632], [-0.1515498989946753]]         3.676908e-02
# 34  [[-2.4952929160389214e-05], [-1.28136342223373...         7.868379e-10
#
#         Time   eta  gamma               start
# 0   0.003649  0.25   0.80      [[0.5], [0.5]]
# 2   0.001025  0.25   0.65      [[0.5], [0.5]]
# 4   0.001211  0.25   0.50      [[0.5], [0.5]]
# 6   4.694794  0.25   0.80        [[-1], [-1]]
# 8   3.096317  0.25   0.65        [[-1], [-1]]
# 10  0.003414  0.25   0.50        [[-1], [-1]]
# 12  7.101004  0.25   0.80  [[-6000], [-5000]]
# 14  2.855705  0.25   0.65  [[-6000], [-5000]]
# 16  0.004539  0.25   0.50  [[-6000], [-5000]]
# 18  0.004767  0.25   0.80    [[6000], [5000]]
# 20  0.003758  0.25   0.65    [[6000], [5000]]
# 22  0.005715  0.25   0.50    [[6000], [5000]]
# 24  0.001747  0.25   0.80       [[5], [-0.5]]
# 26  0.001551  0.25   0.65       [[5], [-0.5]]
# 28  0.001752  0.25   0.50       [[5], [-0.5]]
# 30  8.208475  0.25   0.80       [[-5], [0.5]]
# 32  4.293209  0.25   0.65       [[-5], [0.5]]
# 34  0.002061  0.25   0.50       [[-5], [0.5]]

# %% [markdown]
# #### Análise dos resultados
#  Newton não parece se comportar tão bem como o grandiente quando se trata da descontinuidade. Hipotese: a Hessiana nem sempre fica definida positiva próximo das descontinuidades, ou seja, as direções escolhidas não são de descida.

# %% [markdown]
# ##### 1. Ponto (-5, -0.5) com gamma 0.8

# %%
newt_1 = met_newton([[-5], [-0.5]], 0.0001, 1000, 0.8, 0.25, True)
newt_1[3], newt_1[4]
# Out:
# Iteração:  1
# --------------------
# Ponto:
#  [[-0.99482541]
#  [-0.09221935]]
# Hessiana:
#  [[2.88737271 0.88737271]
#  [0.88737271 1.69200757]]
# Definida Positiva:
#  True
# Singular:
#  False
#
# Iteração:  2
# --------------------
# Ponto:
#  [[-0.14682474]
#  [-0.22794649]]
# Hessiana:
#  [[11.20124722  9.20124722]
#  [ 9.20124722  3.03655357]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  3
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  4
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  5
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  6
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  7
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  8
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  9
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  10
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  11
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  12
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  13
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  14
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  15
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  16
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  17
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  18
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  19
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  20
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  21
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  22
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  23
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  24
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  25
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  26
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  27
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  28
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  29
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  30
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  31
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  32
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  33
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  34
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  35
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  36
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  37
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  38
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  39
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  40
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  41
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  42
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  43
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  44
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  45
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  46
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  47
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  48
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  49
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  50
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  51
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  52
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  53
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  54
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  55
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  56
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  57
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  58
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  59
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  60
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  61
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  62
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  63
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  64
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  65
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  66
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  67
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  68
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  69
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  70
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  71
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  72
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  73
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  74
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  75
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  76
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  77
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  78
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  79
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  80
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  81
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  82
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  83
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  84
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  85
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  86
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  87
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  88
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  89
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  90
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  91
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  92
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  93
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  94
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  95
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  96
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  97
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  98
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  99
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  100
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  101
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  102
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  103
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  104
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  105
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  106
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  107
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  108
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  109
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  110
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  111
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  112
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  113
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  114
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  115
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  116
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  117
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  118
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  119
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  120
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  121
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  122
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  123
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  124
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  125
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  126
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  127
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  128
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  129
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  130
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  131
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  132
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  133
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  134
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  135
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  136
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  137
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  138
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  139
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  140
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  141
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  142
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  143
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  144
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  145
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  146
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  147
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  148
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  149
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  150
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  151
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  152
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  153
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  154
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  155
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  156
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  157
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  158
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  159
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  160
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  161
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  162
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  163
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  164
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  165
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  166
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  167
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  168
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  169
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  170
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  171
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  172
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  173
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  174
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  175
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  176
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  177
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  178
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  179
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  180
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  181
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  182
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  183
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  184
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  185
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  186
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  187
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  188
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  189
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  190
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  191
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  192
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  193
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  194
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  195
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  196
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  197
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  198
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  199
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  200
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  201
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  202
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  203
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  204
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  205
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  206
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  207
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  208
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  209
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  210
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  211
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  212
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  213
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  214
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  215
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  216
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  217
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  218
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  219
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  220
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  221
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  222
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  223
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  224
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  225
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  226
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  227
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  228
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  229
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  230
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  231
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  232
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  233
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  234
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  235
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  236
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  237
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  238
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  239
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  240
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  241
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  242
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  243
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  244
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  245
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  246
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  247
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  248
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  249
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  250
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  251
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  252
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  253
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  254
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  255
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  256
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  257
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  258
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  259
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  260
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# ...
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  915
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  916
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  917
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  918
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  919
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  920
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  921
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  922
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  923
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  924
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  925
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  926
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  927
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  928
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  929
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  930
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  931
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  932
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  933
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  934
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  935
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  936
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  937
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  938
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  939
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  940
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  941
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  942
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  943
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  944
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  945
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  946
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  947
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  948
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  949
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  950
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  951
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  952
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  953
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  954
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  955
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  956
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  957
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  958
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  959
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  960
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  961
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  962
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  963
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  964
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  965
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  966
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  967
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  968
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  969
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  970
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  971
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  972
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  973
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  974
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  975
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  976
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  977
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  978
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  979
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  980
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  981
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  982
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  983
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  984
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  985
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  986
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  987
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  988
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  989
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  990
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  991
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  992
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  993
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  994
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  995
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  996
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  997
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  998
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  999
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  1000
# --------------------
# Ponto:
#  [[-0.03084733]
#  [-0.29189101]]
# Hessiana:
#  [[12.42932635 10.42932635]
#  [10.42932635  3.52516634]]
# Definida Positiva:
#  False
# Singular:
#  False
# (0, 1)

# %% [markdown]
# - Como a Hessiana não é definida positiva nas iterações finais de (-5, -0.5) a direção  escolhida nas últimas iterações não é descida e não há convergência

# %% [markdown]
# ##### 2. Ponto (-1, -1) com gamma 0.5

# %%
newt_2 = met_newton([[-1], [-1]], 0.0001, 1000, 0.5, 0.25, True)
newt_2[3], newt_2[4]
# Out:
# Iteração:  1
# --------------------
# Ponto:
#  [[-0.52291624]
#  [-0.45851883]]
# Hessiana:
#  [[3.19789532 1.19789532]
#  [1.19789532 1.66588578]]
# Definida Positiva:
#  True
# Singular:
#  False
#
# Iteração:  2
# --------------------
# Ponto:
#  [[-0.31276487]
#  [ 0.16437405]]
# Hessiana:
#  [[6.2764348  4.2764348 ]
#  [4.2764348  3.10661683]]
# Definida Positiva:
#  True
# Singular:
#  False
#
# Iteração:  3
# --------------------
# Ponto:
#  [[-0.1416903 ]
#  [-0.07712231]]
# Hessiana:
#  [[11.79987762  9.79987762]
#  [ 9.79987762  4.09048178]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  4
# --------------------
# Ponto:
#  [[-0.11621509]
#  [-0.06342811]]
# Hessiana:
#  [[9.21822256 7.21822256]
#  [7.21822256 3.7222609 ]]
# Definida Positiva:
#  False
# Singular:
#  False
#
# Iteração:  5
# --------------------
# Ponto:
#  [[-0.09860269]
#  [-0.04330514]]
# Hessiana:
#  [[5.64581867 3.64581867]
#  [3.64581867 2.95868747]]
# Definida Positiva:
#  True
# Singular:
#  False
#
# Iteração:  6
# --------------------
# Ponto:
#  [[-0.06176116]
#  [-0.07006205]]
# Hessiana:
#  [[4.70795647 2.70795647]
#  [2.70795647 2.72969801]]
# Definida Positiva:
#  True
# Singular:
#  False
#
# Iteração:  7
# --------------------
# Ponto:
#  [[-0.06936158]
#  [-0.00562554]]
# Hessiana:
#  [[2.04670414 0.04670414]
#  [0.04670414 2.01429844]]
# Definida Positiva:
#  True
# Singular:
#  False
#
# Iteração:  8
# --------------------
# Ponto:
#  [[-0.00163395]
#  [-0.00156821]]
# Hessiana:
#  [[2.00000000e+000 3.23905569e-139]
#  [3.23905569e-139 2.00000000e+000]]
# Definida Positiva:
#  True
# Singular:
#  False
#
# Iteração:  9
# --------------------
# Ponto:
#  [[-0.00081698]
#  [-0.0007841 ]]
# Hessiana:
#  [[2.00000000e+000 5.18462307e-287]
#  [5.18462307e-287 2.00000000e+000]]
# Definida Positiva:
#  True
# Singular:
#  False
#
# Iteração:  10
# --------------------
# Ponto:
#  [[-0.00040849]
#  [-0.00039205]]
# Hessiana:
#  [[2. 0.]
#  [0. 2.]]
# Definida Positiva:
#  True
# Singular:
#  False
#
# Iteração:  11
# --------------------
# Ponto:
#  [[-0.00020424]
#  [-0.00019603]]
# Hessiana:
#  [[2. 0.]
#  [0. 2.]]
# Definida Positiva:
#  True
# Singular:
#  False
#
# Iteração:  12
# --------------------
# Ponto:
#  [[-1.02121882e-04]
#  [-9.80131124e-05]]
# Hessiana:
#  [[2. 0.]
#  [0. 2.]]
# Definida Positiva:
#  True
# Singular:
#  False
#
# Iteração:  13
# --------------------
# Ponto:
#  [[-5.10609411e-05]
#  [-4.90065562e-05]]
# Hessiana:
#  [[2. 0.]
#  [0. 2.]]
# Definida Positiva:
#  True
# Singular:
#  False
#
# Iteração:  14
# --------------------
# Ponto:
#  [[-2.55304706e-05]
#  [-2.45032781e-05]]
# Hessiana:
#  [[2. 0.]
#  [0. 2.]]
# Definida Positiva:
#  True
# Singular:
#  False
# C:\Users\mwuillau\AppData\Local\Temp\ipykernel_2572\3196596769.py:5: RuntimeWarning: divide by zero encountered in double_scalars
#   return 3**(1/(x1+x2))+x1**2+x2**2
# (0, 1)

# %% [markdown]
# - A Hessiana não é definida positiva em todas as iterações, mas Newton converge

# %% [markdown]
# ##### 3. Ponto (6000, 5000) com gamma 0.8

# %%
newt_3 = met_newton([[6000], [5000]], 0.0001, 1000, 0.8, 0.35, True)
newt_3[3], newt_3[4]
# Out:
# Iteração:  1
# --------------------
# Ponto:
#  [[1200.00000769]
#  [1000.02481245]]
# Hessiana:
#  [[2.00000000e+00 1.45384545e-13]
#  [1.45384545e-13 2.00000000e+00]]
# Definida Positiva:
#  True
# Singular:
#  False
#
# Iteração:  2
# --------------------
# Ponto:
#  [[240.00000163]
#  [200.00496266]]
# Hessiana:
#  [[2.00000000e+00 9.10470209e-11]
#  [9.10470209e-11 2.00000003e+00]]
# Definida Positiva:
#  True
# Singular:
#  False
#
# Iteração:  3
# --------------------
# Ponto:
#  [[48.00000262]
#  [40.00099689]]
# Hessiana:
#  [[2.00000006e+00 5.74755377e-08]
#  [5.74755377e-08 2.00000329e+00]]
# Definida Positiva:
#  True
# Singular:
#  False
#
# Iteração:  4
# --------------------
# Ponto:
#  [[9.60006  ]
#  [8.0003105]]
# Hessiana:
#  [[2.00003776e+00 3.77600919e-05]
#  [3.77600919e-05 2.00044235e+00]]
# Definida Positiva:
#  True
# Singular:
#  False
#
# Iteração:  5
# --------------------
# Ponto:
#  [[1.92178772]
#  [1.60313193]]
# Hessiana:
#  [[2.03011421 0.03011421]
#  [0.03011421 2.07919163]]
# Definida Positiva:
#  True
# Singular:
#  False
#
# Iteração:  6
# --------------------
# Ponto:
#  [[0.47204772]
#  [0.43693357]]
# Hessiana:
#  [[18.69892746 16.69892746]
#  [16.69892746 17.71789813]]
# Definida Positiva:
#  True
# Singular:
#  False
#
# Iteração:  7
# --------------------
# Ponto:
#  [[0.51785211]
#  [0.59575764]]
# Hessiana:
#  [[7.93642858 5.93642858]
#  [5.93642858 8.37174355]]
# Definida Positiva:
#  True
# Singular:
#  False
#
# Iteração:  8
# --------------------
# Ponto:
#  [[0.65210308]
#  [0.64203127]]
# Hessiana:
#  [[4.83644311 2.83644311]
#  [2.83644311 5.37493924]]
# Definida Positiva:
#  True
# Singular:
#  False
#
# Iteração:  9
# --------------------
# Ponto:
#  [[0.68128752]
#  [0.67296001]]
# Hessiana:
#  [[4.27789729 2.27789729]
#  [2.27789729 4.79873657]]
# Definida Positiva:
#  True
# Singular:
#  False
#
# Iteração:  10
# --------------------
# Ponto:
#  [[0.67645641]
#  [0.67573401]]
# Hessiana:
#  [[4.29462069 2.29462069]
#  [2.29462069 4.81623705]]
# Definida Positiva:
#  True
# Singular:
#  False
#
# Iteração:  11
# --------------------
# Ponto:
#  [[0.67641956]
#  [0.67627775]]
# Hessiana:
#  [[4.29048581 2.29048581]
#  [2.29048581 4.8119116 ]]
# Definida Positiva:
#  True
# Singular:
#  False
#
# Iteração:  12
# --------------------
# Ponto:
#  [[0.67633426]
#  [0.67632257]]
# Hessiana:
#  [[4.29081563 2.29081563]
#  [2.29081563 4.81225666]]
# Definida Positiva:
#  True
# Singular:
#  False
# C:\Users\mwuillau\AppData\Local\Temp\ipykernel_2572\3196596769.py:5: RuntimeWarning: overflow encountered in double_scalars
#   return 3**(1/(x1+x2))+x1**2+x2**2
# (1, 1)

# %% [markdown]
# - Newton converge e a Hessiana é definida positiva em todas as iterações, ou seja, todas as iterações são de descida

# %% [markdown]
# ## Método Quase Newton

# %% [markdown]
# #### DFP

# %%
def DFP(x_atual,x_antigo,H):
    x_atual = np.array(x_atual)
    x_antigo = np.array(x_antigo)
    p = x_atual - x_antigo
    q = Gradiente(x_atual)- Gradiente(x_antigo)
    if np.linalg.norm(p) != 0 and np.linalg.norm(q) != 0:
        return H + (p@np.transpose(p))/(np.transpose(p)@q) - (H@q@np.transpose(q)@H)/(np.transpose(q)@H@q)
    else: 
        print('pq <= 0')
        return H

# %%
def met_quase_newton_DFP(x,tol,maxiter,gama,n):
    x = np.array(x)
    m = 0
    k =0
    H = np.identity(2)
    while np.linalg.norm(Gradiente(x)) > tol and m < maxiter:
        x_antigo = x
        d = -1*H@Gradiente(x)
        ar = Armijo(x,gama,d,n)
        t = ar[0]
        x = x + t*d
        H = DFP(x,x_antigo,H)
        m = m + 1
        k = k + ar[1]
        
    return [x,m,k]

# %%
tol = 0.0001
maxiter = 1000
result = test_combinations(search, met_quase_newton_DFP, maxiter, tol)       
dfp_res = pd.DataFrame.from_records(result)    
dfp_res[dfp_res['eta'] == 0.25]
# Out:
# C:\Users\mwuillau\AppData\Local\Temp\ipykernel_2572\3196596769.py:5: RuntimeWarning: divide by zero encountered in double_scalars
#   return 3**(1/(x1+x2))+x1**2+x2**2
# C:\Users\mwuillau\AppData\Local\Temp\ipykernel_2572\3196596769.py:5: RuntimeWarning: overflow encountered in double_scalars
#   return 3**(1/(x1+x2))+x1**2+x2**2
#     Armijo Iterations  Method Iterations  \
# 0                  10                  5
# 2                   6                  4
# 4                   4                  5
# 6                  10                  6
# 8                   3                  4
# 10                  3                  5
# 12                 11                 13
# 14                 10                 13
# 16                 18                 20
# 18                 11                 11
# 20                 12                 15
# 22                 16                 17
# 24                  6                  7
# 26                 15                 12
# 28                  4                  7
# 30                  4                  8
# 32                  3                  7
# 34                  5                  7
#
#                                   Optical Point Found  Optical Value Found  \
# 0        [[0.6763353628281227], [0.6763353628281227]]         3.167673e+00
# 2          [[0.676332691443663], [0.676332691443663]]         3.167673e+00
# 4        [[0.6763326473319318], [0.6763326473319318]]         3.167673e+00
# 6   [[-3.516154439006929e-05], [-3.516154439009241...         2.472668e-09
# 8   [[-6.071532165918825e-18], [-1.040834085586084...         1.451971e-34
# 10  [[5.2888737226558513e-17], [-5.532141585107286...         5.857678e-33
# 12        [[0.676335010060589], [0.6763313704115276]]         3.167673e+00
# 14       [[0.6763277833164886], [0.6763333982829317]]         3.167673e+00
# 16  [[-3.7239897350224685e-05], [1.786778325142697...         1.706068e-09
# 18  [[-1.2772953068963789e-05], [8.839925742881646...         2.412926e-10
# 20  [[1.3091191685296556e-05], [-4.724611890679416...         2.403575e-09
# 22       [[0.6763249432024941], [0.6763467262566606]]         3.167673e+00
# 24  [[2.0032737403911276e-06], [-3.828319817984695...         1.469616e-09
# 26  [[3.461387041366289e-05], [-3.462714235634205e...         2.397159e-09
# 28       [[0.6763276916388229], [0.6763296318083035]]         3.167673e+00
# 30       [[0.6763329534674957], [0.6763323710421514]]         3.167673e+00
# 32       [[0.6763321898877384], [0.6763283148505784]]         3.167673e+00
# 34  [[1.0665357201453292e-05], [-1.282602529993365...         2.782568e-10
#
#         Time   eta  gamma               start
# 0   0.001517  0.25   0.80      [[0.5], [0.5]]
# 2   0.001434  0.25   0.65      [[0.5], [0.5]]
# 4   0.001289  0.25   0.50      [[0.5], [0.5]]
# 6   0.004365  0.25   0.80        [[-1], [-1]]
# 8   0.000991  0.25   0.65        [[-1], [-1]]
# 10  0.001166  0.25   0.50        [[-1], [-1]]
# 12  0.007407  0.25   0.80  [[-6000], [-5000]]
# 14  0.002935  0.25   0.65  [[-6000], [-5000]]
# 16  0.007035  0.25   0.50  [[-6000], [-5000]]
# 18  0.003186  0.25   0.80    [[6000], [5000]]
# 20  0.005312  0.25   0.65    [[6000], [5000]]
# 22  0.006980  0.25   0.50    [[6000], [5000]]
# 24  0.001708  0.25   0.80       [[5], [-0.5]]
# 26  0.004853  0.25   0.65       [[5], [-0.5]]
# 28  0.001691  0.25   0.50       [[5], [-0.5]]
# 30  0.002408  0.25   0.80       [[-5], [0.5]]
# 32  0.001871  0.25   0.65       [[-5], [0.5]]
# 34  0.002376  0.25   0.50       [[-5], [0.5]]

# %% [markdown]
# - Os resultads deste método ficaram semelhantes ao método de newton

# %% [markdown]
# #### BFGS

# %%
def Armijo(x,gama,d,n):
    t = 1
    k = 0
    d = np.array(d)
    x = np.array(x)
    while f(x + t*d) > f(x) + n*t*(np.transpose(Gradiente(x))@d):
        t=gama*t
        k = k+1
    return [t,k]

# %%
def BFGS(x_atual,x_antigo,H, debug):
    x_atual = np.array(x_atual)
    x_antigo = np.array(x_antigo)

    p = x_atual - x_antigo
    q = Gradiente(x_atual)- Gradiente(x_antigo)
    if debug:
        print("Vetor p: ",p)
        print("Vetor q: ",p)
    return H + (1 + (np.transpose(q)@H@q)/np.transpose(p)@q)*((p@np.transpose(p))/(np.transpose(q)@q)) - (p@np.transpose(q)@H + H@q@np.transpose(p))/(np.transpose(p)@q)

# %%
def met_quase_newton_BFGS(x,tol,maxiter,gama,n, debug=False):
    x = np.array(x)
    m = 0
    k =0
    df = 1
    H = np.identity(2)
    while np.linalg.norm(Gradiente(x)) > tol and m < maxiter:
        x_antigo = x
        d = -1*H@Gradiente(x)
        ar = Armijo(x,gama,d,n)
        t = ar[0]
        x = x + t*d
        if debug:
            print("\nIteração: " , m)
            print(20*"-")
            print("Ponto:\n" ,x)
            print("Hessiana:\n", H)
            print("Definida Positiva:\n", definida_positiva_2x2(H))
        H = BFGS(x,x_antigo,H, debug)
        m = m + 1
        k = k + ar[1]
    if debug:
        return [x,m,k,df] 
    else:
        return [x,m,k]

# %% [markdown]
# ##### Análise do Erro do método
# No primeiro teste que fizemos a implementação dá erro, pois p ou q são iguais a zero.
#
# Teorema: Quando a hessiana é definida positiva e o t é calculado por busca exata, p*q>0 e a próxima hessiana cálculada é definida positiva.
#
# O problema ta na busca armijo ou na hessiana?

# %%
met_quase_newton_BFGS([[0.5], [0.5]], 0.0001, 1000, 0.8, 0.25)
# Out:
# C:\Users\mwuillau\AppData\Local\Temp\ipykernel_2572\551132956.py:10: RuntimeWarning: invalid value encountered in true_divide
#   return H + (1 + (np.transpose(q)@H@q)/np.transpose(p)@q)*((p@np.transpose(p))/(np.transpose(q)@q)) - (p@np.transpose(q)@H + H@q@np.transpose(p))/(np.transpose(p)@q)
# [array([[nan],
#         [nan]]),
#  5,
#  193]

# %% [markdown]
# - Conclusão as Hessianas são definidas positivas o problema tá no uso da busca de armijo

# %%
tol = 0.0001
maxiter = 1000
result = test_combinations(search, met_quase_newton_BFGS, maxiter, tol)     
bfgs_res = pd.DataFrame.from_records(result)      
bfgs_res
# Out:
# C:\Users\mwuillau\AppData\Local\Temp\ipykernel_2572\551132956.py:10: RuntimeWarning: invalid value encountered in true_divide
#   return H + (1 + (np.transpose(q)@H@q)/np.transpose(p)@q)*((p@np.transpose(p))/(np.transpose(q)@q)) - (p@np.transpose(q)@H + H@q@np.transpose(p))/(np.transpose(p)@q)
# C:\Users\mwuillau\AppData\Local\Temp\ipykernel_2572\3196596769.py:5: RuntimeWarning: overflow encountered in double_scalars
#   return 3**(1/(x1+x2))+x1**2+x2**2
# C:\Users\mwuillau\AppData\Local\Temp\ipykernel_2572\551132956.py:10: RuntimeWarning: divide by zero encountered in true_divide
#   return H + (1 + (np.transpose(q)@H@q)/np.transpose(p)@q)*((p@np.transpose(p))/(np.transpose(q)@q)) - (p@np.transpose(q)@H + H@q@np.transpose(p))/(np.transpose(p)@q)
# C:\Users\mwuillau\AppData\Local\Temp\ipykernel_2572\551132956.py:10: RuntimeWarning: invalid value encountered in matmul
#   return H + (1 + (np.transpose(q)@H@q)/np.transpose(p)@q)*((p@np.transpose(p))/(np.transpose(q)@q)) - (p@np.transpose(q)@H + H@q@np.transpose(p))/(np.transpose(p)@q)
#     Armijo Iterations  Method Iterations  \
# 0                 193                  5
# 1                 257                  6
# 2                 175                  8
# 3                 107                  5
# 4                 169                 12
# 5                  77                  6
# 6                 194                  4
# 7                 194                  4
# 8                 102                  4
# 9                 102                  4
# 10                 61                  5
# 11                 61                  5
# 12               3347                 12
# 13              11082                 20
# 14               1016                  9
# 15               2690                 15
# 16                603                  9
# 17                603                  9
# 18               2907                 11
# 19              12011                 21
# 20               1204                 10
# 21               2718                 15
# 22                604                  9
# 23                604                  9
# 24                255                  5
# 25                448                  7
# 26                134                  5
# 27                134                  5
# 28                 82                  5
# 29                 82                  5
# 30                340                  6
# 31                357                  6
# 32                159                  6
# 33                159                  6
# 34                 84                  5
# 35                 84                  5
#
#                              Optical Point Found  Optical Value Found  \
# 0                                 [[nan], [nan]]                  NaN
# 1                                 [[nan], [nan]]                  NaN
# 2   [[0.6763260400321802], [0.6763260400321802]]             3.167673
# 3                                 [[nan], [nan]]                  NaN
# 4     [[0.676330667239791], [0.676330667239791]]             3.167673
# 5                                 [[nan], [nan]]                  NaN
# 6                                 [[nan], [nan]]                  NaN
# 7                                 [[nan], [nan]]                  NaN
# 8                                 [[nan], [nan]]                  NaN
# 9                                 [[nan], [nan]]                  NaN
# 10                                [[nan], [nan]]                  NaN
# 11                                [[nan], [nan]]                  NaN
# 12                                [[nan], [nan]]                  NaN
# 13                                [[nan], [nan]]                  NaN
# 14                                [[nan], [nan]]                  NaN
# 15                                [[nan], [nan]]                  NaN
# 16                                [[nan], [nan]]                  NaN
# 17                                [[nan], [nan]]                  NaN
# 18                                [[nan], [nan]]                  NaN
# 19                                [[nan], [nan]]                  NaN
# 20                                [[nan], [nan]]                  NaN
# 21                                [[nan], [nan]]                  NaN
# 22                                [[nan], [nan]]                  NaN
# 23                                [[nan], [nan]]                  NaN
# 24                                [[nan], [nan]]                  NaN
# 25                                [[nan], [nan]]                  NaN
# 26                                [[nan], [nan]]                  NaN
# 27                                [[nan], [nan]]                  NaN
# 28                                [[nan], [nan]]                  NaN
# 29                                [[nan], [nan]]                  NaN
# 30                                [[nan], [nan]]                  NaN
# 31                                [[nan], [nan]]                  NaN
# 32                                [[nan], [nan]]                  NaN
# 33                                [[nan], [nan]]                  NaN
# 34                                [[nan], [nan]]                  NaN
# 35                                [[nan], [nan]]                  NaN
#
#         Time   eta  gamma               start
# 0   0.011305  0.25   0.80      [[0.5], [0.5]]
# 1   0.017937  0.10   0.80      [[0.5], [0.5]]
# 2   0.014985  0.25   0.65      [[0.5], [0.5]]
# 3   0.010139  0.10   0.65      [[0.5], [0.5]]
# 4   0.010320  0.25   0.50      [[0.5], [0.5]]
# 5   0.005321  0.10   0.50      [[0.5], [0.5]]
# 6   0.008443  0.25   0.80        [[-1], [-1]]
# 7   0.009939  0.10   0.80        [[-1], [-1]]
# 8   0.004441  0.25   0.65        [[-1], [-1]]
# 9   0.004361  0.10   0.65        [[-1], [-1]]
# 10  0.004189  0.25   0.50        [[-1], [-1]]
# 11  0.003206  0.10   0.50        [[-1], [-1]]
# 12  0.145617  0.25   0.80  [[-6000], [-5000]]
# 13  0.406438  0.10   0.80  [[-6000], [-5000]]
# 14  0.040195  0.25   0.65  [[-6000], [-5000]]
# 15  0.097861  0.10   0.65  [[-6000], [-5000]]
# 16  0.024951  0.25   0.50  [[-6000], [-5000]]
# 17  0.021972  0.10   0.50  [[-6000], [-5000]]
# 18  0.102314  0.25   0.80    [[6000], [5000]]
# 19  0.446449  0.10   0.80    [[6000], [5000]]
# 20  0.048720  0.25   0.65    [[6000], [5000]]
# 21  0.115422  0.10   0.65    [[6000], [5000]]
# 22  0.022707  0.25   0.50    [[6000], [5000]]
# 23  0.023993  0.10   0.50    [[6000], [5000]]
# 24  0.011789  0.25   0.80       [[5], [-0.5]]
# 25  0.021009  0.10   0.80       [[5], [-0.5]]
# 26  0.009917  0.25   0.65       [[5], [-0.5]]
# 27  0.007249  0.10   0.65       [[5], [-0.5]]
# 28  0.003953  0.25   0.50       [[5], [-0.5]]
# 29  0.003685  0.10   0.50       [[5], [-0.5]]
# 30  0.016498  0.25   0.80       [[-5], [0.5]]
# 31  0.017828  0.10   0.80       [[-5], [0.5]]
# 32  0.007123  0.25   0.65       [[-5], [0.5]]
# 33  0.007025  0.10   0.65       [[-5], [0.5]]
# 34  0.003700  0.25   0.50       [[-5], [0.5]]
# 35  0.004028  0.10   0.50       [[-5], [0.5]]

# %% [markdown]
# - Para tentarmos contornar o problema pesquisamos na literatura e encontramos que com certas condições a modificação Armijo poderia retornar um t que é aproximado utilizando também a Heissiana e, assim, melhorar a escolha do passo.
#
#     http://koreascience.kr/article/JAKO200807663775076.pdf

# %%
def Armijo_mod(x,d,H,gama):
    t = 1
    alfa = 0.2
    k = 0
    g = Gradiente(x)
    cache =  alfa*(np.transpose(Gradiente(x))@d + 0.5*t*np.transpose(d)@H@d)
    while f(x + t*d) > f(x) +t*cache:
        t=gama*t
        k = k+1
    return [t,k]

# %%
def met_quase_newton_BFGS_mod(x,tol,maxiter,gama,n, debug=False):
    x = np.array(x)
    m = 0
    k =0
    df = 1
    H = np.identity(2)
    while np.linalg.norm(Gradiente(x)) > tol and m < maxiter:
        x_antigo = x
        d = -1*H@Gradiente(x)
        ar = Armijo_mod(x,d,H,gama)
        t = ar[0]
        x = x + t*d
        if debug:
            print("\nIteração: " , m)
            print(20*"-")
            print("Ponto:\n" ,x)
            print("Hessiana:\n", H)
            print("Definida Positiva:\n", definida_positiva_2x2(H))
        H = BFGS(x,x_antigo,H, debug)
        m = m + 1
        k = k + ar[1]
    if debug:
        return [x,m,k,df] 
    else:
        return [x,m,k]

# %%
met_quase_newton_BFGS_mod([[0.5], [0.5]], 0.0001, 1000, 0.5, 0.25,True)
# Out:
# Iteração:  0
# --------------------
# Ponto:
#  [[0.78697961]
#  [0.78697961]]
# Hessiana:
#  [[1. 0.]
#  [0. 1.]]
# Definida Positiva:
#  True
# Vetor p:  [[0.28697961]
#  [0.28697961]]
# Vetor q:  [[0.28697961]
#  [0.28697961]]
#
# Iteração:  1
# --------------------
# Ponto:
#  [[-0.870969]
#  [-0.870969]]
# Hessiana:
#  [[1.71421443 0.71421443]
#  [0.71421443 1.71421443]]
# Definida Positiva:
#  True
# Vetor p:  [[-1.65794861]
#  [-1.65794861]]
# Vetor q:  [[-1.65794861]
#  [-1.65794861]]
#
# Iteração:  2
# --------------------
# Ponto:
#  [[76.7562797]
#  [76.7562797]]
# Hessiana:
#  [[20.56249781 19.56249781]
#  [19.56249781 20.56249781]]
# Definida Positiva:
#  True
# Vetor p:  [[77.6272487]
#  [77.6272487]]
# Vetor q:  [[77.6272487]
#  [77.6272487]]
#
# Iteração:  3
# --------------------
# Ponto:
#  [[-2.9730805e+08]
#  [-2.9730805e+08]]
# Hessiana:
#  [[968351.94423314 968350.94423314]
#  [968350.94423314 968351.94423314]]
# Definida Positiva:
#  True
# Vetor p:  [[-2.97308126e+08]
#  [-2.97308126e+08]]
# Vetor q:  [[-2.97308126e+08]
#  [-2.97308126e+08]]
#
# Iteração:  4
# --------------------
# Ponto:
#  [[8.14335205e+32]
#  [8.14335205e+32]]
# Hessiana:
#  [[6.84757112e+23 6.84757112e+23]
#  [6.84757112e+23 6.84757112e+23]]
# Definida Positiva:
#  False
# Vetor p:  [[8.14335205e+32]
#  [8.14335205e+32]]
# Vetor q:  [[8.14335205e+32]
#  [8.14335205e+32]]
#
# Iteração:  5
# --------------------
# Ponto:
#  [[-1.18330353e+124]
#  [-1.18330353e+124]]
# Hessiana:
#  [[3.63272865e+90 3.63272865e+90]
#  [3.63272865e+90 3.63272865e+90]]
# Definida Positiva:
#  False
# Vetor p:  [[-1.18330353e+124]
#  [-1.18330353e+124]]
# Vetor q:  [[-1.18330353e+124]
#  [-1.18330353e+124]]
#
# Iteração:  6
# --------------------
# Ponto:
#  [[nan]
#  [nan]]
# Hessiana:
#  [[nan nan]
#  [nan nan]]
# Definida Positiva:
#  False
# Vetor p:  [[nan]
#  [nan]]
# Vetor q:  [[nan]
#  [nan]]
# C:\Users\mwuillau\AppData\Local\Temp\ipykernel_2572\4264350725.py:6: RuntimeWarning: overflow encountered in matmul
#   cache =  alfa*(np.transpose(Gradiente(x))@d + 0.5*t*np.transpose(d)@H@d)
# C:\Users\mwuillau\AppData\Local\Temp\ipykernel_2572\551132956.py:10: RuntimeWarning: overflow encountered in matmul
#   return H + (1 + (np.transpose(q)@H@q)/np.transpose(p)@q)*((p@np.transpose(p))/(np.transpose(q)@q)) - (p@np.transpose(q)@H + H@q@np.transpose(p))/(np.transpose(p)@q)
# C:\Users\mwuillau\AppData\Local\Temp\ipykernel_2572\551132956.py:10: RuntimeWarning: invalid value encountered in subtract
#   return H + (1 + (np.transpose(q)@H@q)/np.transpose(p)@q)*((p@np.transpose(p))/(np.transpose(q)@q)) - (p@np.transpose(q)@H + H@q@np.transpose(p))/(np.transpose(p)@q)
# [array([[nan],
#         [nan]]),
#  7,
#  3,
#  1]

# %% [markdown]
# - Como as condições para esses algoritmos modificado não são atendidos (não atende a cotinuidade Lipschitz), não foi possível obter um resultado.

# %% [markdown]
# ##### Análise dos resultados
# - Somente para o ponto próximo do mínimo local com passo pequeno o método converge

# %% [markdown]
# # Comparação dos Métodos
# <hr/>

# %% [markdown]
# #### Comparação entre DFP e Gradiente

# %% [markdown]
# 1. Número de Iterações

# %%
dfp_conv = dfp_res['Method Iterations'] != 1000
(
    grad_res.loc[dfp_conv, 'Method Iterations'] >= dfp_res.loc[dfp_conv, 'Method Iterations']
).sum(), (dfp_res['Method Iterations'] != 1000).sum()
# Out:
# (29, 36)

# %% [markdown]
# - O método DFP apresenta menos iterações

# %% [markdown]
# 2. Tempo

# %%
dfp_conv = dfp_res['Method Iterations'] != 1000
(
    grad_res.loc[dfp_conv, 'Time'] >= dfp_res.loc[dfp_conv, 'Time']
).sum(), (dfp_res['Method Iterations'] != 1000).sum()
# Out:
# (16, 36)

# %%
print('DFP vs Grad')
dfp_res.loc[18:23, ['Time', 'start']], grad_res.loc[18:23, ['Time', 'start']]
# Out:
# DFP vs Grad
# (        Time             start
#  18  0.003186  [[6000], [5000]]
#  19  0.007210  [[6000], [5000]]
#  20  0.005312  [[6000], [5000]]
#  21  0.004704  [[6000], [5000]]
#  22  0.006980  [[6000], [5000]]
#  23  0.004244  [[6000], [5000]],
#          Time             start
#  18  0.002526  [[6000], [5000]]
#  19  0.005140  [[6000], [5000]]
#  20  0.002334  [[6000], [5000]]
#  21  0.001411  [[6000], [5000]]
#  22  0.002452  [[6000], [5000]]
#  23  0.004861  [[6000], [5000]])

# %% [markdown]
# - mesmo analisando apenas os números pontos iniciais grandes, o gradiente ainda consegue ser mais lento que o DFP em alguns testes

# %% [markdown]
# 3. Número de iterações de armijo

# %%
dfp_conv = dfp_res['Armijo Iterations'] != 1000
(
    grad_res.loc[dfp_conv, 'Armijo Iterations'] >= dfp_res.loc[dfp_conv, 'Method Iterations']
).sum(), (dfp_res['Method Iterations'] != 1000).sum()
# Out:
# (36, 36)

# %% [markdown]
# - O gradiente apresenta mais iterações de Armijo em todos os testes,

# %% [markdown]
# #### Comparação entre Newton e Gradiente
#
# Acreditamos que Newton performou melhor que o gradiente devido aos critérios abaixo, isso pode ter relação com o fato de Newton realizar uma aproximação quadrática da função e a nossa função ter aspectos de uma função quadrática, delocada por $3^{\frac{1}{x_1+x_2}}$.

# %% [markdown]
# 1. Número de Iterações

# %%
newton_conv = newton_res['Method Iterations'] != 1000
(
    grad_res.loc[newton_conv, 'Method Iterations'] >= newton_res.loc[newton_conv, 'Method Iterations']
).sum(), (newton_res['Method Iterations'] != 1000).sum()
# Out:
# (22, 24)

# %% [markdown]
# - O método de newton apresenta menos iterações

# %% [markdown]
# 2. Tempo

# %%
newton_conv = newton_res['Method Iterations'] != 1000
(
    grad_res.loc[newton_conv, 'Time'] >= newton_res.loc[newton_conv, 'Time']
).sum(), (newton_res['Method Iterations'] != 1000).sum()
# Out:
# (10, 24)

# %%
print('Newton vs Grad')
newton_res.loc[18:23, ['Time', 'start']], grad_res.loc[18:23, ['Time', 'start']]
# Out:
# Newton vs Grad
# (        Time             start
#  18  0.004767  [[6000], [5000]]
#  19  0.002984  [[6000], [5000]]
#  20  0.003758  [[6000], [5000]]
#  21  0.003365  [[6000], [5000]]
#  22  0.005715  [[6000], [5000]]
#  23  0.004902  [[6000], [5000]],
#          Time             start
#  18  0.002526  [[6000], [5000]]
#  19  0.005140  [[6000], [5000]]
#  20  0.002334  [[6000], [5000]]
#  21  0.001411  [[6000], [5000]]
#  22  0.002452  [[6000], [5000]]
#  23  0.004861  [[6000], [5000]])

# %% [markdown]
# - mesmo analisando apenas os números pontos iniciais grandes, o gradiente ainda consegue ser mais lento que o newton em alguns casos analisados

# %% [markdown]
# 3. Número de iterações de armijo

# %%
newton_conv = newton_res['Armijo Iterations'] != 1000
(
    grad_res.loc[newton_conv, 'Armijo Iterations'] >= newton_res.loc[newton_conv, 'Method Iterations']
).sum(), (newton_res['Method Iterations'] != 1000).sum()
# Out:
# (24, 24)

# %% [markdown]
# - O gradiente apresenta mais iterações de Armijo em todos os testes,

# %% [markdown]
# #### Comparação entre DFP e Newton

# %% [markdown]
# 1. Número de Iterações

# %%
newton_conv = newton_res['Method Iterations'] != 1000
dfp_conv = dfp_res['Method Iterations'] != 1000
(
    newton_res.loc[newton_conv&dfp_conv, 'Method Iterations'] >= dfp_res.loc[newton_conv&dfp_conv, 'Method Iterations']
).sum(), (newton_conv&dfp_conv).sum()
# Out:
# (15, 24)

# %% [markdown]
# - O método DFP apresenta menos iterações, na maioria das iterações

# %% [markdown]
# 2. Tempo

# %%
newton_conv = newton_res['Method Iterations'] != 1000
dfp_conv = dfp_res['Method Iterations'] != 1000
(
    newton_res.loc[newton_conv&dfp_conv, 'Time'] >= dfp_res.loc[newton_conv&dfp_conv, 'Time']
).sum(), (newton_conv&dfp_conv).sum()
# Out:
# (8, 24)

# %%
print('DFP vs Newton')
newton_res.loc[18:23, ['Time', 'start']], grad_res.loc[18:23, ['Time', 'start']]
# Out:
# DFP vs Newton
# (        Time             start
#  18  0.004767  [[6000], [5000]]
#  19  0.002984  [[6000], [5000]]
#  20  0.003758  [[6000], [5000]]
#  21  0.003365  [[6000], [5000]]
#  22  0.005715  [[6000], [5000]]
#  23  0.004902  [[6000], [5000]],
#          Time             start
#  18  0.002526  [[6000], [5000]]
#  19  0.005140  [[6000], [5000]]
#  20  0.002334  [[6000], [5000]]
#  21  0.001411  [[6000], [5000]]
#  22  0.002452  [[6000], [5000]]
#  23  0.004861  [[6000], [5000]])

# %% [markdown]
# 3. Número de iterações de armijo

# %%
newton_conv = newton_res['Method Iterations'] != 1000
dfp_conv = dfp_res['Method Iterations'] != 1000
(
    newton_res.loc[newton_conv&dfp_conv, 'Armijo Iterations'] >= dfp_res.loc[newton_conv&dfp_conv, 'Armijo Iterations']
).sum(), (newton_conv&dfp_conv).sum()
# Out:
# (19, 24)

# %% [markdown]
# - O newton apresenta mais iterações de Armijo na maioria dos casos, quando comparado com DFP
